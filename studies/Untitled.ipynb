# %%
import pandas as pd

# %%
obs = pd.read_csv('/mnt/d/_Gabriel/Estudo/UFF/PMN/hourly_data.csv')

# %%
obs
# Out:
#        Unnamed: 0        Lat        lon           estação   cidade  \
# 0               0 -22.885602 -43.104860         Boa Vista  Niterói
# 1               1 -22.882610 -43.065750          Caramujo  Niterói
# 2               2 -22.912318 -43.102392           Cavalão  Niterói
# 3               3 -22.934441 -43.006239   Engenho do Mato  Niterói
# 4               4 -22.934441 -43.006239            Itaipú  Niterói
# ...           ...        ...        ...               ...      ...
# 26123          25 -22.899628 -43.118460   Morro do Estado  Niterói
# 26124          26 -22.934162 -43.100285       Preventório  Niterói
# 26125          27 -22.876405 -43.046370   Santa Bárbara 2  Niterói
# 26126          28 -22.902903 -43.086738  Travessa Beltrão  Niterói
# 26127          29 -22.863960 -43.099190         Barreto 1  Niterói
#
#                    data  chuva 15m chuva 1h chuva 4h chuva 24h chuva 96h  \
# 0      21/03/2022 20:15        0.0      0.0      0.2       7.8       7.8
# ...

# %%
b = obs.where(obs['estação']=='Barreto 1').dropna()
b
# Out:
#        Unnamed: 0       Lat       lon    estação   cidade              data  \
# 29           29.0 -22.86396 -43.09919  Barreto 1  Niterói  21/03/2022 20:15
# 59           59.0 -22.86396 -43.09919  Barreto 1  Niterói  21/03/2022 20:15
# 89           89.0 -22.86396 -43.09919  Barreto 1  Niterói  21/03/2022 20:15
# 119         119.0 -22.86396 -43.09919  Barreto 1  Niterói  21/03/2022 20:15
# 149         149.0 -22.86396 -43.09919  Barreto 1  Niterói  23/03/2022 19:45
# ...           ...       ...       ...        ...      ...               ...
# 26007     26007.0 -22.86396 -43.09919  Barreto 1  Niterói  29/04/2022 17:00
# 26037     26037.0 -22.86396 -43.09919  Barreto 1  Niterói  29/04/2022 18:00
# 26067     26067.0 -22.86396 -43.09919  Barreto 1  Niterói  29/04/2022 19:00
# 26097     26097.0 -22.86396 -43.09919  Barreto 1  Niterói  29/04/2022 19:45
# 26127        29.0 -22.86396 -43.09919  Barreto 1  Niterói  29/04/2022 19:45
#
# ...

# %%
df_values = b[['chuva 15m', 'chuva 1h', 'chuva 4h', 'chuva 24h', 'chuva 96h', 'chuva 30d']]
for cada in df_values:
    b[cada] = df_values[cada].apply(lambda x: sep_fix(x))

# %%
b
# Out:
#        Unnamed: 0       Lat       lon    estação   cidade              data  \
# 29           29.0 -22.86396 -43.09919  Barreto 1  Niterói  21/03/2022 20:15
# 59           59.0 -22.86396 -43.09919  Barreto 1  Niterói  21/03/2022 20:15
# 89           89.0 -22.86396 -43.09919  Barreto 1  Niterói  21/03/2022 20:15
# 119         119.0 -22.86396 -43.09919  Barreto 1  Niterói  21/03/2022 20:15
# 149         149.0 -22.86396 -43.09919  Barreto 1  Niterói  23/03/2022 19:45
# ...           ...       ...       ...        ...      ...               ...
# 26007     26007.0 -22.86396 -43.09919  Barreto 1  Niterói  29/04/2022 17:00
# 26037     26037.0 -22.86396 -43.09919  Barreto 1  Niterói  29/04/2022 18:00
# 26067     26067.0 -22.86396 -43.09919  Barreto 1  Niterói  29/04/2022 19:00
# 26097     26097.0 -22.86396 -43.09919  Barreto 1  Niterói  29/04/2022 19:45
# 26127        29.0 -22.86396 -43.09919  Barreto 1  Niterói  29/04/2022 19:45
#
# ...

# %%
def float_converter(one):
    ''' Some precipitation values are coming with the '0.0.1' format, so this function
        drops the last '.' and converts the value to float type.
        
    '''
    try:
        fixed_float = float(one)
    except:
        separ = one.split('.')
        comma = one.split('.')[0]+'.'
        fixed_float = float(comma+''.join(one.split('.')[1:]))
        
    return fixed_float

# %%
b['data'] = pd.to_datetime(b['data'])
b['Date'] = b['data'].apply(lambda x: x.date())
# Out:
#        Unnamed: 0       Lat       lon    estação   cidade                data  \
# 29           29.0 -22.86396 -43.09919  Barreto 1  Niterói 2022-03-21 20:15:00
# 59           59.0 -22.86396 -43.09919  Barreto 1  Niterói 2022-03-21 20:15:00
# 89           89.0 -22.86396 -43.09919  Barreto 1  Niterói 2022-03-21 20:15:00
# 119         119.0 -22.86396 -43.09919  Barreto 1  Niterói 2022-03-21 20:15:00
# 149         149.0 -22.86396 -43.09919  Barreto 1  Niterói 2022-03-23 19:45:00
# ...           ...       ...       ...        ...      ...                 ...
# 26007     26007.0 -22.86396 -43.09919  Barreto 1  Niterói 2022-04-29 17:00:00
# 26037     26037.0 -22.86396 -43.09919  Barreto 1  Niterói 2022-04-29 18:00:00
# 26067     26067.0 -22.86396 -43.09919  Barreto 1  Niterói 2022-04-29 19:00:00
# 26097     26097.0 -22.86396 -43.09919  Barreto 1  Niterói 2022-04-29 19:45:00
# 26127        29.0 -22.86396 -43.09919  Barreto 1  Niterói 2022-04-29 19:45:00
#
# ...

# %%
sort = b.drop('Unnamed: 0', axis=1).sort_values('Date')
sort['Date'].unique()
# Out:
# array([datetime.date(2022, 1, 4), datetime.date(2022, 2, 4),
#        datetime.date(2022, 3, 4), datetime.date(2022, 3, 21),
#        datetime.date(2022, 3, 23), datetime.date(2022, 3, 24),
#        datetime.date(2022, 3, 25), datetime.date(2022, 3, 26),
#        datetime.date(2022, 3, 27), datetime.date(2022, 3, 28),
#        datetime.date(2022, 3, 29), datetime.date(2022, 3, 30),
#        datetime.date(2022, 3, 31), datetime.date(2022, 4, 4),
#        datetime.date(2022, 4, 13), datetime.date(2022, 4, 14),
#        datetime.date(2022, 4, 15), datetime.date(2022, 4, 16),
#        datetime.date(2022, 4, 17), datetime.date(2022, 4, 18),
#        datetime.date(2022, 4, 19), datetime.date(2022, 4, 20),
#        datetime.date(2022, 4, 21), datetime.date(2022, 4, 22),
#        datetime.date(2022, 4, 23), datetime.date(2022, 4, 24),
#        datetime.date(2022, 4, 25), datetime.date(2022, 4, 26),
#        datetime.date(2022, 4, 27), datetime.date(2022, 4, 28),
# ...

# %%
import sys
sys.path.append('/home/github/RNA_Operacional_WRF')
import API_output_treatment as api_t

# %%
obs
# Out:
#        Unnamed: 0        Lat        lon           estação   cidade  \
# 0               0 -22.885602 -43.104860         Boa Vista  Niterói
# 1               1 -22.882610 -43.065750          Caramujo  Niterói
# 2               2 -22.912318 -43.102392           Cavalão  Niterói
# 3               3 -22.934441 -43.006239   Engenho do Mato  Niterói
# 4               4 -22.934441 -43.006239            Itaipú  Niterói
# ...           ...        ...        ...               ...      ...
# 26123          25 -22.899628 -43.118460   Morro do Estado  Niterói
# 26124          26 -22.934162 -43.100285       Preventório  Niterói
# 26125          27 -22.876405 -43.046370   Santa Bárbara 2  Niterói
# 26126          28 -22.902903 -43.086738  Travessa Beltrão  Niterói
# 26127          29 -22.863960 -43.099190         Barreto 1  Niterói
#
#                    data  chuva 15m chuva 1h chuva 4h chuva 24h chuva 96h  \
# 0      21/03/2022 20:15        0.0      0.0      0.2       7.8       7.8
# ...

# %%
api_t.API_treatment(obs)
# Out:
#        Unnamed: 0        Lat        lon           estação   cidade  \
# 0               0 -22.885602 -43.104860         Boa Vista  Niterói
# 1               1 -22.882610 -43.065750          Caramujo  Niterói
# 2               2 -22.912318 -43.102392           Cavalão  Niterói
# 3               3 -22.934441 -43.006239   Engenho do Mato  Niterói
# 4               4 -22.934441 -43.006239            Itaipú  Niterói
# ...           ...        ...        ...               ...      ...
# 26123          25 -22.899628 -43.118460   Morro do Estado  Niterói
# 26124          26 -22.934162 -43.100285       Preventório  Niterói
# 26125          27 -22.876405 -43.046370   Santa Bárbara 2  Niterói
# 26126          28 -22.902903 -43.086738  Travessa Beltrão  Niterói
# 26127          29 -22.863960 -43.099190         Barreto 1  Niterói
#
#                    data  chuva 15m  chuva 1h  chuva 4h  chuva 24h  chuva 96h  \
# 0      21/03/2022 20:15        0.0      0.00      0.20       7.80       7.80
# ...
