# %%
import pandas as pd
import xarray as xr
import numpy as np

# %%
import os
os.listdir('/home/data/PMN/')
# Out:
# ['2.Meteorologicos',
#  'wrfout_d04_2020-04-26_00_00_00:Zone.Identifier',
#  'WRF_Barreto_10-7_20-10',
#  'WRF_extrai_rn',
#  '1.Pluviometricos',
#  'wrf_netcdf_ex',
#  'Pluviometricos',
#  'rna_input.csv:Zone.Identifier',
#  'rna_input.csv']

# %%
ds = xr.open_dataset('/home/data/PMN/wrf_netcdf_ex.nc')
#-22.86396;-43.09919;Barreto 1;

# %%
rain = ds.RAINSH

# %%
rain
# Out:
# <xarray.DataArray 'RAINSH' (Time: 97, south_north: 60, west_east: 51)>
# [296820 values with dtype=float32]
# Coordinates:
#     XLAT     (Time, south_north, west_east) float32 -23.12 -23.12 ... -22.58
#     XLONG    (Time, south_north, west_east) float32 -43.41 -43.4 ... -42.91
#     XTIME    (Time) datetime64[ns] 2020-04-26 2020-04-26T01:00:00 ... 2020-04-30
# Dimensions without coordinates: Time, south_north, west_east
# Attributes:
#     FieldType:    104
#     MemoryOrder:  XY
#     description:  ACCUMULATED SHALLOW CUMULUS PRECIPITATION
#     units:        mm
#     stagger:

# %%
barreto_ds = rain.where((rain['XLAT']==-22.86396))
barreto_ds
# Out:
#   File "<ipython-input-44-f2290cc47b6d>", line 1
#     barreto_ds = rain.where((rain['XLAT']==-22.86396)))
#                                                       ^
# SyntaxError: unmatched ')'

# %%
barreto_ds
# Out:
# <xarray.DataArray 'RAINSH' (Time: 97, south_north: 60, west_east: 51)>
# array([[[nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         ...,
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan]],
#
#        [[nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         ...,
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan]],
#
#        [[nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         ...,
# ...
#         ...,
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan]],
#
# ...
