# %%
import pandas as pd

# %%
saida = pd.read_csv('saida_2.csv', sep=';',encoding='latin-1',usecols=[13])
saida
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_21232/3806872462.py in <module>
# ----> 1 saida = pd.read_csv('saida_2.csv', sep=';',encoding='latin-1',usecols=[13])
#       2 saida
#
# c:\ProgramData\Anaconda3\envs\norsk\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
pd.read_csv("altered_saida.csv")
# Out:
#                   Column2                  Column3  Column4  Column5  Column6  \
# 0        18/02/2020 20:45  20DCNIT18/02/2020 20:45        0        0        0
# 1        18/02/2020 20:45  21DCNIT18/02/2020 20:45        0        0        0
# 2        18/02/2020 20:45  22DCNIT18/02/2020 20:45        0        0        0
# 3        18/02/2020 20:45  36DCNIT18/02/2020 20:45        0        0        0
# 4        18/02/2020 20:45  18DCNIT18/02/2020 20:45        0        0        0
# ...                   ...                      ...      ...      ...      ...
# 1048570  08/03/2021 13:30  30DCNIT08/03/2021 13:30        0        0        0
# 1048571  08/03/2021 13:30  31DCNIT08/03/2021 13:30        0        0        0
# 1048572  08/03/2021 13:30  24DCNIT08/03/2021 13:30        0        0        0
# 1048573  08/03/2021 13:45  18DCNIT08/03/2021 13:45        0        0        0
# 1048574  08/03/2021 13:45  20DCNIT08/03/2021 13:45        0        0        0
#
# ...
